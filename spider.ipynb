# %%
import requests


proxies = {
    "http": "socks5://127.0.0.1:10808",
    'https': 'socks5://127.0.0.1:10808'
}
headers = {
    'referer' : 'https://www.showmebug.com/',
    'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36',
    
}
base_url = 'https://www.tiktok.com/@sophie.seddon?lang=en'

# %%
response = requests.get(base_url , headers= headers, proxies=proxies)

# %%
print(response.text)
# Out:
# <!DOCTYPE html><html lang="en" pc="yes">
#         <head>
#         <script>
#
#     window._I18N_LANG_ = 'en';
# ...

# %%
from TikTokApi import TikTokApi
api = TikTokApi()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-4-2b31a591a821> in <module>
#       1 from TikTokApi import TikTokApi
# ----> 2 api = TikTokApi()
#       3
#
# d:\program files\python\python37\lib\site-packages\TikTokApi\tiktok.py in __init__(self, **kwargs)
#      54         self.signer_url = kwargs.get("external_signer", None)
#      55         if self.signer_url is None:
# ---> 56             self.browser = browser(**kwargs)
#      57             self.userAgent = self.browser.userAgent
#      58
#
# d:\program files\python\python37\lib\site-packages\TikTokApi\browser.py in __init__(self, **kwargs)
#      80             )
#      81         except Exception as e:
# ---> 82             raise e
#      83             logging.critical(e)
#      84
#
# d:\program files\python\python37\lib\site-packages\TikTokApi\browser.py in __init__(self, **kwargs)
#      76
# ...

# %%
username = 'kourtneykardashian'

# %%
user_videos = api.byUsername(username,count=100, proxies = proxies, headers = headers)

# %%
print(user_videos)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-6c518f9ece51> in <module>
# ----> 1 print(user_videos)
#       2
#
# NameError: name 'user_videos' is not defined

# %%
import re

pattern = re.compile('authorStats\":(.*?),\"privateItem' , re.S)

info = re.findall(pattern , response.text)
info = eval(info[0])

# %%
# following
following = info['followingCount']
follower = info['followerCount']

# like 
like = info['heartCount']

# %%
pattern1 = re.compile('\"author\":(.*?),\"music\":' , re.S)
author = re.findall(pattern1 , response.text)[1]
print(author)
# Out:
# {"id":"6675959103535744006","shortId":"0","uniqueId":"sophie.seddon","nickname":"Sophie Seddon","avatarLarger":"https://p16-sign-sg.tiktokcdn.com/aweme/1080x1080/tos-alisg-avt-0068/37c6f3795194dec789e6e5ea55a1f984.jpeg?x-expires=1610017200\u0026x-signature=2Ba%2FpYI%2Ba43E29iEh2YTj68EoVw%3D","avatarMedium":"https://p16-sign-sg.tiktokcdn.com/aweme/720x720/tos-alisg-avt-0068/37c6f3795194dec789e6e5ea55a1f984.jpeg?x-expires=1610017200\u0026x-signature=TI8QmNAHtAPhxMEDBx3Uz2Zk1vY%3D","avatarThumb":"https://p77-sign-sg.tiktokcdn.com/aweme/100x100/tos-alisg-avt-0068/37c6f3795194dec789e6e5ea55a1f984.jpeg?x-expires=1610017200\u0026x-signature=d54QXBCE8jpiihk8wuCtMfJ38Lo%3D","signature":"sophieseddon@whalarstars.com","createTime":1554367956,"verified":true,"secUid":"MS4wLjABAAAA0zF8w3E5Exqf8cB3qs37V428uTjqJQd6haBq9q9Lp4KagqdoJHiGh4GV0LIS9bNm","ftc":false,"relation":0,"openFavorite":false,"commentSetting":0,"duetSetting":0,"stitchSetting":0,"privateAccount":false,"secret":false}

# %%
author_info = eval(author.replace('true','True').replace('false','False'))
# 名称
name = author_info['uniqueId']
# 签名
signature = author_info['signature']

# %%
url1 = 'https://m.tiktok.com/node/share/discover?_signature=_02B4Z6wo00f01U3HikQAAIDC.TZmjFLI5TVNxo7AAAyF9a'
# suggestedaccount_url = 'https://m.tiktok.com/node/share/discover?aid=1988&app_name=tiktok_web&device_platform=web&referer=https:%2F%2Fwww.showmebug.com%2F&root_referer=https:%2F%2Fwww.showmebug.com%2F&user_agent=Mozilla%2F5.0+(Windows+NT+10.0%3B+Win64%3B+x64)+AppleWebKit%2F537.36+(KHTML,+like+Gecko)+Chrome%2F85.0.4183.121+Safari%2F537.36&cookie_enabled=true&screen_width=1549&screen_height=872&browser_language=zh-CN&browser_platform=Win32&browser_name=Mozilla&browser_version=5.0+(Windows+NT+10.0%3B+Win64%3B+x64)+AppleWebKit%2F537.36+(KHTML,+like+Gecko)+Chrome%2F85.0.4183.121+Safari%2F537.36&browser_online=true&ac=3g&timezone_name=Asia%2FShanghai&priority_region=&verifyFp=verify_kjl7ez3h_XM3d7nKr_TYAj_4nm4_82Jz_euiZipo4JahG&appId=1233&region=IE&appType=m&isAndroid=false&isMobile=false&isIOS=false&OS=windows&did=6914571750861899270&noUser=0&userCount=30&scene=15&_signature=_02B4Z6wo00f01U3HikQAAIDC.TZmjFLI5TVNxo7AAAyF9a'
response1 = requests.get(url1 , headers = headers, proxies = proxies)
print(response1.text)
# Out:
# {"body":[{"exploreList":[{"cardItem":{"id":"6609953078064316422","type":2,"cover":"https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/97e17a140f85004e0f034a66d6c97f41~c5_100x100.jpeg?x-expires=1610020800&x-signature=6TqX1cZWD7dNJdyjSUlxsNUvKng%3D","title":"Cowbelly’s Memes","subTitle":"@memes","description":"🐧Memes by Cowbelly Studios🐧\n🤝 Original Content 🤝\nJoin the Discord 🤠🤠🤠🤠🤠","link":"/@memes","round":true,"playToken":"","keyToken":"","extraInfo":{"verified":false,"fans":13000000,"likes":"624700000","userId":"6609953078064316422","secUid":"MS4wLjABAAAAX54piwGamOVF15gItDU9cnoXFtj1PCL8c6_KJo4GmFTvSG2_ob7DWqYamzifNmXp","relation":-1}}},{"cardItem":{"id":"6588038589333094406","type":2,"cover":"https://p16-sign-sg.tiktokcdn.com/tos-maliva-avt-0068/1c6079a079088360cc31e363fc836e26~c5_100x100.jpeg?x-expires=1610020800&x-signature=kZQ5tBt7Gpr9%2FpQ9GtO8U5%2BeJ8g%3D","title":"Andrea & Lewis","subTitle":"@andreaandlewis","description":"👇🏼this was the SWEETEST thing ever 🥺❤️👇🏼","link":
# ...

# %%
suggestedaccounts = eval(response1.text.replace('true','True').replace('false','False').replace('null','1'))

# %%
# 全部信息
suggestedaccounts_info = suggestedaccounts["body"][0]["exploreList"]
print(suggestedaccounts_info)
# Out:
# [{'cardItem': {'id': '6609953078064316422', 'type': 2, 'cover': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/97e17a140f85004e0f034a66d6c97f41~c5_100x100.jpeg?x-expires=1610020800&x-signature=6TqX1cZWD7dNJdyjSUlxsNUvKng%3D', 'title': 'Cowbelly’s Memes', 'subTitle': '@memes', 'description': '🐧Memes by Cowbelly Studios🐧\n🤝 Original Content 🤝\nJoin the Discord 🤠🤠🤠🤠🤠', 'link': '/@memes', 'round': True, 'playToken': '', 'keyToken': '', 'extraInfo': {'verified': False, 'fans': 13000000, 'likes': '624700000', 'userId': '6609953078064316422', 'secUid': 'MS4wLjABAAAAX54piwGamOVF15gItDU9cnoXFtj1PCL8c6_KJo4GmFTvSG2_ob7DWqYamzifNmXp', 'relation': -1}}}, {'cardItem': {'id': '6588038589333094406', 'type': 2, 'cover': 'https://p16-sign-sg.tiktokcdn.com/tos-maliva-avt-0068/1c6079a079088360cc31e363fc836e26~c5_100x100.jpeg?x-expires=1610020800&x-signature=kZQ5tBt7Gpr9%2FpQ9GtO8U5%2BeJ8g%3D', 'title': 'Andrea & Lewis', 'subTitle': '@andreaandlewis', 'description': '👇🏼this was the SWEETEST thi
# ...
